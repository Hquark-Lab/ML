# %% [markdown]
# ## 索引

# %%
import numpy as np

# %%
a = np.arange(8)

# %%
a[-1]
# Out:
# np.int64(7)

# %%
a[3:5]
# Out:
# array([3, 4])

# %%
a[4:]
# Out:
# array([4, 5, 6, 7])

# %%
a[]
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
a[::3]
# Out:
# array([0, 3, 6])

# %%
a[::-1]#倒序输出
# Out:
# array([7, 6, 5, 4, 3, 2, 1, 0])

# %%
A = np.array([
    [1,2,3,4,5],
    [4,5,6,7,8],
    [5,8,4,7,7]
])

# %%
A[-1]
# Out:
# array([5, 8, 4, 7, 7])

# %%
A[1:,0]
# Out:
# array([4, 5])

# %%
A[:2,:3]
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
X = A[:2,:3].copy() #注意深拷贝和浅拷贝

# %%
X[0,0] = 100

# %%
A[0,0]
# Out:
# np.int64(1)
